# %% [markdown]
# <a href="https://colab.research.google.com/github/stay110807-cmyk/OPP/blob/main/lab1_P1_ToledoDorado_DIegoEmmanuel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 1. Creating a class, object, attibute and methods
# Student: Toledo Dorado Diego Emmanuel
# Object-oriented programming 4°B BIS

# %% [markdown]
# In this lab you are going to explore and create a program that defines a class called Backpage

# %%
class backpage:
    def __init__(self, color, sizes, types):
        self.color = color
        self.sizes = sizes
        self.types = types

    def save(self):
        print("The backpage is saving objects")

    def transport(self):
        print("The backpage is transporting objects")

    def order(self):
        print("The backpage is ordering objects")

    def describe(self):
        print(f"This backpage is color {self.color}", f"size {self.sizes}",
            f"and the type is {self.types}")

backpage1 = backpage("blue","big","school")
backpage2 = backpage("red", "small", "sport")

print(backpage1.color)
print(backpage1.types)

backpage1.transport()
backpage2.describe()

print(backpage2.color)
# Out:
# blue
# school
# The backpage is transporting objects
# This backpage is color red size small and the type is sport
# red

# %% [markdown]
# #Lab 1: Bank Account Class
#
# create a pyhton program that models a bank account using  Object-Oriented Programming
